# %%
# https://exupery-1.tistory.com/206

# %%
import numpy as np
import pylab as pl

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score 

from sklearn.model_selection import StratifiedKFold 
from sklearn.model_selection import GridSearchCV  

import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
import numpy as np

from numpy.random import seed # 예측 결과 일정하게 하기 위함
seed(1) # 예측 결과 일정하게 하기 위함
import tensorflow as tf  # 예측 결과 일정하게 하기 위함
tf.random.set_seed(2) # 예측 결과 일정하게 하기 위함

# %%
data = pd.read_csv("bladder_cancer.csv")
data.head(3)
# Out:
#       Amp_1MHz  Phase_1MHz   Amp_500kHz  Phase_500kHz   Amp_100kHz  \
# 0  1826.379159  -83.458529  3578.605538    -85.824932  17848.77353
# 1  1822.430390  -83.707765  3588.429488    -85.421176  17537.29920
# 2  1824.105505  -83.823186  3532.988697    -85.372390  16429.97769
#
#    Phase_100kHz    Amp_50kHz  Phase_50kHz    Amp_10kHz  Phase_10kHz  Label
# 0    -85.555033  30923.77481   -84.679487  121151.8394   -79.349716      1
# 1    -87.164969  31855.09213   -88.802440  121616.4272   -78.980499      1
# 2    -87.916345  31066.25861   -83.519898  121313.6036   -79.646773      1

# %%
# pd.set_option('display.max_rows',None) # pandas 의 row 값을 모두 보고 싶을 때 설정하는 option
data.isnull().sum()
# Out:
# Amp_1MHz        0
# Phase_1MHz      0
# Amp_500kHz      0
# Phase_500kHz    0
# Amp_100kHz      0
# Phase_100kHz    0
# Amp_50kHz       0
# Phase_50kHz     0
# Amp_10kHz       0
# Phase_10kHz     0
# Label           0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Amp_1MHz        0
# Phase_1MHz      0
# Amp_500kHz      0
# Phase_500kHz    0
# Amp_100kHz      0
# Phase_100kHz    0
# Amp_50kHz       0
# Phase_50kHz     0
# Amp_10kHz       0
# Phase_10kHz     0
# Label           0
# dtype: int64

# %%
data[0:1]
# Out:
#       Amp_1MHz  Phase_1MHz   Amp_500kHz  Phase_500kHz   Amp_100kHz  \
# 0  1826.379159  -83.458529  3578.605538    -85.824932  17848.77353
#
#    Phase_100kHz    Amp_50kHz  Phase_50kHz    Amp_10kHz  Phase_10kHz  Label
# 0    -85.555033  30923.77481   -84.679487  121151.8394   -79.349716      1

# %%
X = data.drop(columns=['Label'], axis=1)
y = data['Label']

# %%
# train_set with cross-validation : test_set = 80 : 20 
train_feature, test_feature, train_label, test_label = train_test_split(X, y, test_size = 0.2,random_state=0)

# %%
print(train_feature.shape)
print(test_feature.shape)
print(train_label.shape)
print(test_label.shape)
# Out:
# (188, 10)
# (48, 10)
# (188,)
# (48,)

# %%
# feature normalization, label 은 normalization 진행하지 않았음
scaler = StandardScaler() # scaler 객체 생성
scaler.fit(train_feature) # train_feature 의 mean 과 standard deviation 값을 추출
train_feature_scaled = scaler.transform(train_feature) # train_feature 의 정규화 진행
test_feature_scaled = scaler.transform(test_feature) # test_feature 의 정규화 진행.
# test_feature 는 mean 과 standard deviation 값을 추출하는 과정 하면 안됨. 
# 학습할 때와 동일한 기반 설정으로 동일하게 테스트 데이터를 변환되야 함.

# %%
# pandas numpy 로 변환
train_label = np.array(train_label)
test_label = np.array(test_label)

# %%
# k-Fold Cross Validation
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import EarlyStopping

n_fold=5
skf = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=42)

accuracy=[]



for train_index, validation_index in skf.split(train_feature_scaled,train_label):
  model = tf.keras.models.Sequential([tf.keras.layers.Dense(248, input_dim=10, activation='relu'),
                                      tf.keras.layers.Dense(208, activation='relu'),
                                      tf.keras.layers.Dense(208, activation='relu'),
                                      tf.keras.layers.Dense(208, activation='relu'),
                                      tf.keras.layers.Dense(367, activation='relu'),
                                      tf.keras.layers.Dense(367, activation='relu'),
                                      tf.keras.layers.Dense(1, activation='sigmoid')
                                      ])

  optimizer = keras.optimizers.Adam(learning_rate=0.0006192615305934411)
  model.compile(loss="binary_crossentropy",
              optimizer=optimizer,
              metrics=['accuracy'])
  
  history = model.fit(train_feature_scaled[train_index], train_label[train_index]
                      ,validation_data=(train_feature_scaled[validation_index],train_label[validation_index])
                      ,epochs=173
                      ,batch_size=117
                      ,callbacks=EarlyStopping(monitor='val_loss',patience=10)
                      )
  # callbacks=EarlyStopping(monitor='loss',patience=10)
  
  accuracy_history = history.history['accuracy'] # training data accuracy
  val_accuracy_history = history.history['val_accuracy'] # validation data accuracy
  loss_history = history.history['loss'] # training data loss
  val_loss_history = history.history['val_loss'] # training data loss


  k_accuracy = f"{model.evaluate(train_feature_scaled[validation_index],train_label[validation_index])[1]:.4f}"
  accuracy.append([k_accuracy,accuracy_history,val_accuracy_history, loss_history, val_loss_history])
# Out:
# Epoch 1/173
# 2/2 [==============================] - 1s 144ms/step - loss: 0.6920 - accuracy: 0.5533 - val_loss: 0.6723 - val_accuracy: 0.7368
# Epoch 2/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6583 - accuracy: 0.8400 - val_loss: 0.6394 - val_accuracy: 0.7632
# Epoch 3/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6138 - accuracy: 0.8467 - val_loss: 0.5908 - val_accuracy: 0.8158
# Epoch 4/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5428 - accuracy: 0.8467 - val_loss: 0.5345 - val_accuracy: 0.8158
# Epoch 5/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4499 - accuracy: 0.8733 - val_loss: 0.4916 - val_accuracy: 0.8158
# Epoch 6/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3495 - accuracy: 0.8733 - val_loss: 0.4974 - val_accuracy: 0.8158
# Epoch 7/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2702 - accuracy: 0.8933 - val_loss: 0.5418 - val_accuracy: 0.8158
# Epoch 8/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2100 - accuracy: 0.9133 - val_loss: 0.5611 - val_accuracy: 0.8421
# Epoch 9/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1607 - accuracy: 0.9267 - val_loss: 0.6449 - val_accuracy: 0.8421
# Epoch 10/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1191 - accuracy: 0.9467 - val_loss: 0.6823 - val_accuracy: 0.8684
# Epoch 11/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0817 - accuracy: 0.9733 - val_loss: 0.5658 - val_accuracy: 0.8421
# Epoch 12/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0711 - accuracy: 0.9733 - val_loss: 0.6246 - val_accuracy: 0.8421
# Epoch 13/173
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0419 - accuracy: 0.9800 - val_loss: 0.8080 - val_accuracy: 0.8421
# Epoch 14/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0305 - accuracy: 0.9933 - val_loss: 0.8317 - val_accuracy: 0.8158
# Epoch 15/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.7372 - val_accuracy: 0.8684
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7372 - accuracy: 0.8684
# Epoch 1/173
# 2/2 [==============================] - 0s 116ms/step - loss: 0.6916 - accuracy: 0.5467 - val_loss: 0.6686 - val_accuracy: 0.8684
# Epoch 2/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6590 - accuracy: 0.8533 - val_loss: 0.6336 - val_accuracy: 0.8158
# Epoch 3/173
# 2/2 [==============================] - 0s 23ms/step - loss: 0.6148 - accuracy: 0.8400 - val_loss: 0.5687 - val_accuracy: 0.8421
# Epoch 4/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5449 - accuracy: 0.8600 - val_loss: 0.4768 - val_accuracy: 0.8684
# Epoch 5/173
# 2/2 [==============================] - 0s 18ms/step - loss: 0.4535 - accuracy: 0.8667 - val_loss: 0.3781 - val_accuracy: 0.8684
# Epoch 6/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3533 - accuracy: 0.9000 - val_loss: 0.2937 - val_accuracy: 0.8684
# Epoch 7/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2809 - accuracy: 0.9133 - val_loss: 0.2464 - val_accuracy: 0.8684
# Epoch 8/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2377 - accuracy: 0.9200 - val_loss: 0.2222 - val_accuracy: 0.8947
# Epoch 9/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1934 - accuracy: 0.9467 - val_loss: 0.2569 - val_accuracy: 0.8947
# Epoch 10/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1479 - accuracy: 0.9400 - val_loss: 0.2708 - val_accuracy: 0.8947
# Epoch 11/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1122 - accuracy: 0.9667 - val_loss: 0.2183 - val_accuracy: 0.8947
# Epoch 12/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0759 - accuracy: 0.9733 - val_loss: 0.2314 - val_accuracy: 0.8947
# Epoch 13/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0512 - accuracy: 0.9800 - val_loss: 0.3478 - val_accuracy: 0.8947
# Epoch 14/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0405 - accuracy: 0.9933 - val_loss: 0.3674 - val_accuracy: 0.9211
# Epoch 15/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0286 - accuracy: 0.9933 - val_loss: 0.2872 - val_accuracy: 0.8947
# Epoch 16/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.2710 - val_accuracy: 0.8421
# Epoch 17/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.2995 - val_accuracy: 0.8684
# Epoch 18/173
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.3897 - val_accuracy: 0.8947
# Epoch 19/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4608 - val_accuracy: 0.9211
# Epoch 20/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4307 - val_accuracy: 0.8947
# Epoch 21/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3694 - val_accuracy: 0.8684
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3694 - accuracy: 0.8684
# Epoch 1/173
# 2/2 [==============================] - 0s 120ms/step - loss: 0.6884 - accuracy: 0.5667 - val_loss: 0.6565 - val_accuracy: 0.6579
# Epoch 2/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6480 - accuracy: 0.7933 - val_loss: 0.6113 - val_accuracy: 0.7105
# Epoch 3/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5966 - accuracy: 0.8267 - val_loss: 0.5542 - val_accuracy: 0.7368
# Epoch 4/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5191 - accuracy: 0.8400 - val_loss: 0.5046 - val_accuracy: 0.7368
# Epoch 5/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4494 - accuracy: 0.8400 - val_loss: 0.4228 - val_accuracy: 0.7895
# Epoch 6/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3751 - accuracy: 0.8667 - val_loss: 0.3348 - val_accuracy: 0.8158
# Epoch 7/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.3241 - accuracy: 0.8600 - val_loss: 0.3750 - val_accuracy: 0.8421
# Epoch 8/173
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2963 - accuracy: 0.9000 - val_loss: 0.3560 - val_accuracy: 0.8684
# Epoch 9/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2214 - accuracy: 0.9267 - val_loss: 0.2760 - val_accuracy: 0.8421
# Epoch 10/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2491 - accuracy: 0.8933 - val_loss: 0.2678 - val_accuracy: 0.8421
# Epoch 11/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1614 - accuracy: 0.9600 - val_loss: 0.3771 - val_accuracy: 0.8684
# Epoch 12/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1575 - accuracy: 0.9467 - val_loss: 0.4318 - val_accuracy: 0.8684
# Epoch 13/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1389 - accuracy: 0.9533 - val_loss: 0.2595 - val_accuracy: 0.8684
# Epoch 14/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0908 - accuracy: 0.9800 - val_loss: 0.1906 - val_accuracy: 0.8947
# Epoch 15/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0936 - accuracy: 0.9733 - val_loss: 0.1753 - val_accuracy: 0.8947
# Epoch 16/173
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0675 - accuracy: 0.9733 - val_loss: 0.2037 - val_accuracy: 0.9211
# Epoch 17/173
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0396 - accuracy: 0.9933 - val_loss: 0.2570 - val_accuracy: 0.8684
# Epoch 18/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.8947
# Epoch 19/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.8684
# Epoch 20/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9211
# Epoch 21/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.2165 - val_accuracy: 0.9211
# Epoch 22/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.8947
# Epoch 23/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.8684
# Epoch 24/173
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2158 - val_accuracy: 0.8947
# Epoch 25/173
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2258 - val_accuracy: 0.8947
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2258 - accuracy: 0.8947
# Epoch 1/173
# 2/2 [==============================] - 1s 124ms/step - loss: 0.6897 - accuracy: 0.4702 - val_loss: 0.6762 - val_accuracy: 0.5946
# Epoch 2/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6538 - accuracy: 0.6556 - val_loss: 0.6536 - val_accuracy: 0.7027
# Epoch 3/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6077 - accuracy: 0.7748 - val_loss: 0.6203 - val_accuracy: 0.7027
# Epoch 4/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.5450 - accuracy: 0.7815 - val_loss: 0.5850 - val_accuracy: 0.7297
# Epoch 5/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4707 - accuracy: 0.8278 - val_loss: 0.5555 - val_accuracy: 0.7297
# Epoch 6/173
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3829 - accuracy: 0.8742 - val_loss: 0.5626 - val_accuracy: 0.7297
# Epoch 7/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3168 - accuracy: 0.8808 - val_loss: 0.6207 - val_accuracy: 0.7297
# Epoch 8/173
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2757 - accuracy: 0.9073 - val_loss: 0.5737 - val_accuracy: 0.7027
# Epoch 9/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2123 - accuracy: 0.9205 - val_loss: 0.5854 - val_accuracy: 0.7027
# Epoch 10/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2133 - accuracy: 0.9272 - val_loss: 0.5603 - val_accuracy: 0.7838
# Epoch 11/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1401 - accuracy: 0.9404 - val_loss: 0.6756 - val_accuracy: 0.7297
# Epoch 12/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1278 - accuracy: 0.9603 - val_loss: 0.6328 - val_accuracy: 0.7297
# Epoch 13/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0826 - accuracy: 0.9801 - val_loss: 0.5788 - val_accuracy: 0.8108
# Epoch 14/173
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0633 - accuracy: 0.9735 - val_loss: 0.5946 - val_accuracy: 0.8108
# Epoch 15/173
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0388 - accuracy: 1.0000 - val_loss: 0.6623 - val_accuracy: 0.7838
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6623 - accuracy: 0.7838
# Epoch 1/173
# 2/2 [==============================] - 1s 118ms/step - loss: 0.6913 - accuracy: 0.5298 - val_loss: 0.6742 - val_accuracy: 0.7027
# Epoch 2/173
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6681 - accuracy: 0.6954 - val_loss: 0.6526 - val_accuracy: 0.6757
# Epoch 3/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6396 - accuracy: 0.6556 - val_loss: 0.6189 - val_accuracy: 0.7297
# Epoch 4/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5960 - accuracy: 0.7947 - val_loss: 0.5704 - val_accuracy: 0.8108
# Epoch 5/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5359 - accuracy: 0.8675 - val_loss: 0.5132 - val_accuracy: 0.8378
# Epoch 6/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4623 - accuracy: 0.8411 - val_loss: 0.4536 - val_accuracy: 0.8649
# Epoch 7/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.3844 - accuracy: 0.8477 - val_loss: 0.3850 - val_accuracy: 0.8649
# Epoch 8/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3106 - accuracy: 0.8543 - val_loss: 0.3397 - val_accuracy: 0.8378
# Epoch 9/173
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2518 - accuracy: 0.9007 - val_loss: 0.3534 - val_accuracy: 0.8108
# Epoch 10/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2056 - accuracy: 0.9139 - val_loss: 0.3434 - val_accuracy: 0.8108
# Epoch 11/173
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1660 - accuracy: 0.9404 - val_loss: 0.3177 - val_accuracy: 0.8919
# Epoch 12/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1400 - accuracy: 0.9536 - val_loss: 0.3277 - val_accuracy: 0.8378
# Epoch 13/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1112 - accuracy: 0.9735 - val_loss: 0.3648 - val_accuracy: 0.8649
# Epoch 14/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0835 - accuracy: 0.9801 - val_loss: 0.3961 - val_accuracy: 0.8919
# Epoch 15/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0635 - accuracy: 0.9934 - val_loss: 0.3201 - val_accuracy: 0.8919
# Epoch 16/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0397 - accuracy: 0.9934 - val_loss: 0.1958 - val_accuracy: 0.8649
# Epoch 17/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0222 - accuracy: 0.9934 - val_loss: 0.1426 - val_accuracy: 0.9189
# Epoch 18/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9189
# Epoch 19/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9189
# Epoch 20/173
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9459
# Epoch 21/173
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 1.0000
# Epoch 22/173
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9730
# Epoch 23/173
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9189
# Epoch 24/173
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.9189
# Epoch 25/173
# 2/2 [==============================] - 0s 19ms/step - loss: 9.4702e-04 - accuracy: 1.0000 - val_loss: 0.3065 - val_accuracy: 0.9189
# Epoch 26/173
# 2/2 [==============================] - 0s 19ms/step - loss: 8.1926e-04 - accuracy: 1.0000 - val_loss: 0.3268 - val_accuracy: 0.9189
# Epoch 27/173
# 2/2 [==============================] - 0s 19ms/step - loss: 6.4116e-04 - accuracy: 1.0000 - val_loss: 0.3062 - val_accuracy: 0.9189
# Epoch 28/173
# 2/2 [==============================] - 0s 20ms/step - loss: 4.3839e-04 - accuracy: 1.0000 - val_loss: 0.2712 - val_accuracy: 0.9189
# Epoch 29/173
# 2/2 [==============================] - 0s 18ms/step - loss: 3.1284e-04 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.9189
# Epoch 30/173
# 2/2 [==============================] - 0s 19ms/step - loss: 2.3669e-04 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.9189
# Epoch 31/173
# 2/2 [==============================] - 0s 19ms/step - loss: 1.9470e-04 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 0.9459
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1770 - accuracy: 0.9459

# %%
model.evaluate(test_feature_scaled, test_label)

model.evaluate(test_feature_scaled, test_label)

# epoch 를 200 까지 늘리니 loss 값이 좀 늘어남. accuracy 는 그대로 0.9375
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2309 - accuracy: 0.9167
# 2/2 [==============================] - 0s 0s/step - loss: 0.2309 - accuracy: 0.9167
# [0.23094172775745392, 0.9166666865348816]

# %%
# print(accuracy_history)

# %%
# print(val_accuracy_history)

# %%
print(k_accuracy)
# Out:
# 0.9459

# %%
# accuracy

# %%
## Visualize history
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
colours = 'krgby'
for i in range(n_fold):
  # plt.plot(accuracy[i][1],marker='.',c=colours[i],label=str(i+1)+"-fold")
  plt.plot(accuracy[i][2],marker='.',c=colours[i], label=str(i+1)+"-fold") # 각각의 fold 마다 accuracy 출력
plt.ylim(0.5,1.0)
plt.grid()
plt.legend()
plt.title('Prediction accuracy using validation dataset with respect to epochs at each fold')
# Out:
# Text(0.5, 1.0, 'Prediction accuracy using validation dataset with respect to epochs at each fold')

# %%
## Visualize history
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
colours = 'krgby'
for i in range(n_fold):
  # plt.plot(accuracy[i][1],marker='.',c=colours[i],label=str(i+1)+"-fold")
  plt.plot(accuracy[i][3],marker='.',c=colours[i], label=str(i+1)+"-fold") # 각각의 fold 마다 accuracy 출력
#plt.ylim(0,1.0)
plt.grid()
plt.legend()
plt.title('Loss using train dataset with respect to epochs at each fold')
# Out:
# Text(0.5, 1.0, 'Loss using train dataset with respect to epochs at each fold')

# %%
## Visualize history
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
colours = 'krgby'
for i in range(n_fold):
  # plt.plot(accuracy[i][1],marker='.',c=colours[i],label=str(i+1)+"-fold")
  plt.plot(accuracy[i][4],marker='.',c=colours[i], label=str(i+1)+"-fold") # 각각의 fold 마다 accuracy 출력
#plt.ylim(0,1.0)
plt.grid()
plt.legend()
plt.title('Loss using validation dataset with respect to epochs at each fold')
# Out:
# Text(0.5, 1.0, 'Loss using validation dataset with respect to epochs at each fold')

# %%
print(accuracy[0][2])
print(np.array(accuracy[0][2]))
# Out:
# [0.7368420958518982, 0.7631579041481018, 0.8157894611358643, 0.8157894611358643, 0.8157894611358643, 0.8157894611358643, 0.8157894611358643, 0.8421052694320679, 0.8421052694320679, 0.8684210777282715, 0.8421052694320679, 0.8421052694320679, 0.8421052694320679, 0.8157894611358643, 0.8684210777282715]
# [0.7368421  0.7631579  0.81578946 0.81578946 0.81578946 0.81578946
#  0.81578946 0.84210527 0.84210527 0.86842108 0.84210527 0.84210527
#  0.84210527 0.81578946 0.86842108]

# %%
# averaging validation accuracy

# %%
validation_accuracy_sum = 0
validation_accuracy_mean = 0

for i in range(n_fold):
    validation_accuracy_sum = validation_accuracy_sum + np.array(accuracy[i][2]) 
    
validation_accuracy_mean = validation_accuracy_sum/n_fold
    
print(validation_accuracy_mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a65012a77ce5> in <module>
#       3
#       4 for i in range(n_fold):
# ----> 5     validation_accuracy_sum = validation_accuracy_sum + np.array(accuracy[i][2])
#       6
#       7 validation_accuracy_mean = validation_accuracy_sum/n_fold
#
# ValueError: operands could not be broadcast together with shapes (15,) (21,)

# %%
## Visualize history
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
colours = 'krgby'
for i in range(n_fold):
  # plt.plot(accuracy[i][1],marker='.',c=colours[i],label=str(i+1)+"-fold")
  plt.plot(validation_accuracy_mean, marker='.') # 각각의 fold 마다 accuracy 출력
plt.ylim(0.5,1.0)
plt.grid()
# plt.legend()
plt.title('Everage prediction accuracy using validation dataset with respect to epochs at each fold')
# Out:
# Text(0.5, 1.0, 'Everage prediction accuracy using validation dataset with respect to epochs at each fold')

# %%
# averaging validation loss

# %%
validation_loss_sum = 0
validation_loss_mean = 0

for i in range(n_fold):
    validation_loss_sum = validation_loss_sum + np.array(accuracy[i][4]) 
    
validation_loss_mean = validation_loss_sum/n_fold
    
print(validation_loss_mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\user\Desktop\Python_langauge\AI\Bladder_C\Bayesian optimization_fitting.ipynb Cell 27' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Python_langauge/AI/Bladder_C/Bayesian%20optimization_fitting.ipynb#ch0000026?line=1'>2</a> validation_loss_mean = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Python_langauge/AI/Bladder_C/Bayesian%20optimization_fitting.ipynb#ch0000026?line=3'>4</a> for i in range(n_fold):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Python_langauge/AI/Bladder_C/Bayesian%20optimization_fitting.ipynb#ch0000026?line=4'>5</a>     validation_loss_sum = validation_loss_sum + np.array(accuracy[i][4])
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Python_langauge/AI/Bladder_C/Bayesian%20optimization_fitting.ipynb#ch0000026?line=6'>7</a> validation_loss_mean = validation_loss_sum/n_fold
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Python_langauge/AI/Bladder_C/Bayesian%20optimization_fitting.ipynb#ch0000026?line=8'>9</a> print(validation_loss_mean)
#
# ValueError: operands could not be broadcast together with shapes (57,) (114,)

# %%
## Visualize history
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
colours = 'krgby'
for i in range(n_fold):
  # plt.plot(accuracy[i][1],marker='.',c=colours[i],label=str(i+1)+"-fold")
  plt.plot(validation_loss_mean, marker='.') # 각각의 fold 마다 accuracy 출력
plt.ylim(0,1.0)
plt.grid()
# plt.legend()
plt.title('Everage prediction loss using validation dataset with respect to epochs at each fold')
# Out:
# Text(0.5, 1.0, 'Everage prediction loss using validation dataset with respect to epochs at each fold')

# %%
np.argmin(validation_loss_mean)
# Out:
# 172
